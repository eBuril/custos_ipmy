# %%
c = 4.44
f = 21.75 / 14
l = (0.3799) + ((14.9 * 4)/30) + ((8.61 * 3)/30) + ((5.7 / 100) * 3)
t = 6

# %%
tc = (t * c) * 30
tf = (t * f) * 30
tl = (t * l) * 30
tcil = tc + tl + tf

# %%
print(l)
print(f)
print (tc)
print (tf)
print (tl)
print (tcil)
print (tc + tl)
# Out:
# 3.398566666666667
# 1.5535714285714286
# 799.2
# 279.6428571428571
# 611.7420000000001
# 1690.5848571428571
# 1410.942

# %%
s = (28.97/30)
f1 = 21.75 / 14
l1 = (0.3799) + ((8.61 * 3)/30) + ((5.7 / 100) * 3)
t1 = 6

# %%
ts = (t1 * s) * 30
tf1 = (t1 * f1) * 30
tl1 = (t1 * l1) * 30
total = ts + tl1 + tf1

# %%
print(s)
print(l1)
print (ts)
print (tf1)
print (tl1)
print (total)
print (ts + tl1)
# Out:
# 0.9656666666666667
# 1.4119
# 173.82000000000002
# 279.6428571428571
# 254.14199999999997
# 707.6048571428571
# 427.962

# %%
v = 150 / 2

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (8,4)
x = ["HydroSil" , "SpeediCath", "Vilar Cath"]
y = [tcil , total, v]
plt.xlabel("Tipos de Terapêutica",weight='bold', fontsize='large')
plt.ylabel("Gastos para 01 mês",weight='bold', fontsize='large')
plt.title("Custo Mensal por Tipo de Tratamento em Euros", weight='bold', fontsize='x-large')
bar_color = 'green', '#e197ab', '#2b3078'
width_n = 0.7
plt.bar(x, y, color=bar_color, width=width_n, align='center')
plt.show()

# %%
itu = 3090.30
cil = 520.39
v = 800

# %%
m_itu = itu * 2.5
a_cil = cil *12
t_cons = m_itu + a_cil
a_v = v * 6
e = t_cons - a_v
ex = ((e)/t_cons)*100

print(m_itu)
print(a_cil)
print(t_cons)
print(a_v)
print(e)
print(ex)
# Out:
# 7725.75
# 6244.68
# 13970.43
# 4800
# 9170.43
# 65.64171611038458

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (8,4)
x = ["Tratamento Conservador", "Vilar Cath"]
y = [t_cons, a_v]
plt.xlabel("Tipos de Terapêutica",weight='bold', fontsize='large', color='#2b3078')
plt.ylabel("Custo anual médio",weight='bold', fontsize='large', color='#2b3078')
plt.title("Custo Anual por Tipo de Tratamento", weight='bold', fontsize='x-large', color='#2b3078')
bar_color = '#e197ab', '#2b3078'
width_n = 0.7
plt.bar(x, y, color=bar_color, width=width_n, align='center')
plt.show()

# %%
itu = 3090.30
cila = 617.35
v = 800

# %%
m_itu = itu * 2.5
a_cila = cila * 12
t_consa = m_itu + a_cila
a_v = v * 6
e= t_consa - a_v
ex = (e / t_consa)*100

print(m_itu)
print(a_cila)
print(t_consa)
print(a_v)
print(e)
print(ex)
# Out:
# 7725.75
# 7408.200000000001
# 15133.95
# 4800
# 10333.95
# 68.28323074940779

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (8,4)
x = ["Tratamento Conservador", "Vilar Cath"]
y = [t_consa, a_v]
plt.xlabel("Tipos de Terapêutica",weight='bold', fontsize='large', color='#2b3078')
plt.ylabel("Custo anual médio",weight='bold', fontsize='large', color='#2b3078')
plt.title("Custo Anual por Tipo de Tratamento", weight='bold', fontsize='x-large', color='#2b3078')
bar_color = '#e197ab', '#2b3078'
width_n = 0.7
plt.bar(x, y, color=bar_color, width=width_n, align='center')
plt.show()
